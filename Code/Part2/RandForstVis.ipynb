# %%
import matplotlib.pyplot as plt
#import plotly.graph_objects as go

# Bar chart example using Matplotlib
x = [
    '5-fold default parameters',
    '10-fold default parameters',
    '5-fold cross-validation with max_depth=5',
    '5-fold cross-validation with max_depth=20',
    '5-fold cross-validation with max_depth=50',
    '5-fold cross-validation with max_depth=35',
    '5-fold cross-validation with max_features=5',
    '5-fold cross-validation with max_features=10',
    '10-fold cross-validation with unique parameters'
]
accuracy = [
    0.8498642845237103, 0.8518476246041006, 0.7206620746173293,
    0.844597505347668, 0.8485809192432703, 0.8487809234102842,
    0.7960466288857405, 0.8350807108925743, 0.8696145579818859
]

fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(x, accuracy)
ax.set_title('Accuracy of Random Forest Model')
ax.set_xlabel('Cross Validation')
ax.set_ylabel('Accuracy')

plt.xticks(rotation=45)
plt.subplots_adjust(top=0.9, bottom=0.2)  # Manually adjust the margins

plt.show()

# Histogram example using Plotly
hist_data = [accuracy]
group_labels = ['Accuracy']

fig = go.Figure()
for i, data in enumerate(hist_data):
    fig.add_trace(go.Histogram(x=data, name=group_labels[i]))

fig.update_layout(
    title='Accuracy Distribution of Random Forest Model',
    xaxis_title='Accuracy',
    yaxis_title='Count'
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9032/2527277915.py in <module>
#      36 group_labels = ['Accuracy']
#      37
# ---> 38 fig = go.Figure()
#      39 for i, data in enumerate(hist_data):
#      40     fig.add_trace(go.Histogram(x=data, name=group_labels[i]))
#
# NameError: name 'go' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Results data
labels = [
    'Default (5-fold CV)', 'Default (10-fold CV)', 'max_depth=5 (5-fold CV)',
    'max_depth=20 (5-fold CV)', 'max_depth=50 (5-fold CV)', 'max_depth=35 (5-fold CV)',
    'max_features=5 (5-fold CV)', 'max_features=10 (5-fold CV)', 'Unique Parameters (10-fold CV)'
]

accuracies = [
    0.8498642845237103, 0.8518476246041006, 0.7206620746173293, 0.844597505347668,
    0.8485809192432703, 0.8487809234102842, 0.7960466288857405, 0.8350807108925743,
    0.8696145579818859
]

f1_scores = [
    0.6507215979718446, 0.6562012460890234, 0.168417748023534, 0.6377781061822454,
    0.6497511557476886, 0.6488135696172306, 0.49479969780623934, 0.6127577677303335,
    0.7003238103122598
]

training_accuracies = [
    0.9999166653645564, 0.999914813408753, 0.7228578852337202, 0.9678911319333041,
    0.9977791294263074, 0.9907706789898401, 0.9999291654513636, 0.999920832031223,
    0.967030932534416
]

training_f1_scores = [
    0.9998938545119331, 0.9998930069970788, 0.17938183795553145, 0.9408241651481708,
    0.9961438634760311, 0.9835923894012069, 0.9999206118021174, 0.9999114460683203,
    0.9391370917123293
]

# Plotting
x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots(figsize=(18, 6))

rects1 = ax.bar(x - width, accuracies, width, label='Accuracy')
rects2 = ax.bar(x, f1_scores, width, label='F1 Score')
rects3 = ax.bar(x + width, training_accuracies, width, label='Training Accuracy')
rects4 = ax.bar(x + (2 * width), training_f1_scores, width, label='Training F1 Score')

ax.set_ylabel('Scores')
ax.set_title('Random Forest Results')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)
ax.legend()
ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
# Add data labels
def add_labels(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.3f}', xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points", ha='center', va='bottom')

add_labels(rects1)
add_labels(rects2)
add_labels(rects3)
add_labels(rects4)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Results data
default_labels = ['Default (5-fold CV)', 'Default (10-fold CV)']
default_accuracies = [0.8498642845237103, 0.8518476246041006]
default_f1_scores = [0.6507215979718446, 0.6562012460890234]
default_training_accuracies = [0.9999166653645564, 0.999914813408753]
default_training_f1_scores = [0.9998938545119331, 0.9998930069970788]

max_depth_labels = [
    'max_depth=5 (5-fold CV)', 'max_depth=20 (5-fold CV)', 'max_depth=50 (5-fold CV)',
    'max_depth=35 (5-fold CV)'
]
max_depth_accuracies = [0.7206620746173293, 0.844597505347668, 0.8485809192432703, 0.8487809234102842]
max_depth_f1_scores = [0.168417748023534, 0.6377781061822454, 0.6497511557476886, 0.6488135696172306]
max_depth_training_accuracies = [0.7228578852337202, 0.9678911319333041, 0.9977791294263074, 0.9907706789898401]
max_depth_training_f1_scores = [0.17938183795553145, 0.9408241651481708, 0.9961438634760311, 0.9835923894012069]

max_features_labels = ['max_features=5 (5-fold CV)', 'max_features=10 (5-fold CV)']
max_features_accuracies = [0.7960466288857405, 0.8350807108925743]
max_features_f1_scores = [0.49479969780623934, 0.6127577677303335]
max_features_training_accuracies = [0.9999291654513636, 0.999920832031223]
max_features_training_f1_scores = [0.9999206118021174, 0.9999114460683203]

unique_labels = ['Unique Parameters (10-fold CV)']
unique_accuracies = [0.8696145579818859]
unique_f1_scores = [0.7003238103122598]
unique_training_accuracies = [0.967030932534416]
unique_training_f1_scores = [0.9391370917123293]

# Plotting
fig, axs = plt.subplots(4, 2, figsize=(18, 12))

# Default
axs[0, 0].bar(default_labels, default_accuracies, label='Accuracy')
axs[0, 0].bar(default_labels, default_f1_scores, label='F1 Score')
axs[0, 0].set_title('Default')
axs[0, 0].legend()

axs[1, 0].bar(default_labels, default_training_accuracies, label='Training Accuracy')
axs[1, 0].bar(default_labels, default_training_f1_scores, label='Training F1 Score')
axs[1, 0].legend()

# max_depth
axs[0, 1].bar(max_depth_labels, max_depth_accuracies, label='Accuracy')
axs[0, 1].bar(max_depth_labels, max_depth_f1_scores, label='F1 Score')
axs[0, 1].set_title('max_depth')
axs[0, 1].legend()

axs[1, 1].bar(max_depth_labels, max_depth_training_accuracies, label='Training Accuracy')
axs[1, 1].bar(max_depth_labels, max_depth_training_f1_scores, label='Training F1 Score')
axs[1, 1].legend()

# max_features
axs[2, 0].bar(max_features_labels, max_features_accuracies, label='Accuracy')
axs[2, 0].bar(max_features_labels, max_features_f1_scores, label='F1 Score')
axs[2, 0].set_title('max_features')
axs[2, 0].legend()

axs[3, 0].bar(max_features_labels, max_features_training_accuracies, label='Training Accuracy')
axs[3, 0].bar(max_features_labels, max_features_training_f1_scores, label='Training F1 Score')
axs[3, 0].legend()

# Unique Parameters
axs[2, 1].bar(unique_labels, unique_accuracies, label='Accuracy')
axs[2, 1].bar(unique_labels, unique_f1_scores, label='F1 Score')
axs[2, 1].set_title('Unique Parameters')
axs[2, 1].legend()

axs[3, 1].bar(unique_labels, unique_training_accuracies, label='Training Accuracy')
axs[3, 1].bar(unique_labels, unique_training_f1_scores, label='Training F1 Score')
axs[3, 1].legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Results data
labels_default = ['Default (5-fold CV)', 'Default (10-fold CV)']
labels_max_depth = ['Max Depth=5 (5-fold CV)', 'Max Depth=20 (5-fold CV)', 'Max Depth=50 (5-fold CV)', 'Max Depth=35 (5-fold CV)']
labels_max_features = ['Max Features=5 (5-fold CV)', 'Max Features=10 (5-fold CV)']
labels_unique_params = ['Unique Parameters (10-fold CV)']

accuracies_default = [0.8498642845237103, 0.8518476246041006]
accuracies_max_depth = [0.7206620746173293, 0.844597505347668, 0.8485809192432703, 0.8487809234102842]
accuracies_max_features = [0.7960466288857405, 0.8350807108925743]
accuracies_unique_params = [0.8696145579818859]

training_accuracies_default = [0.9999166653645564, 0.999914813408753]
training_accuracies_max_depth = [0.7228578852337202, 0.9678911319333041, 0.9977791294263074, 0.9907706789898401]
training_accuracies_max_features = [0.9999291654513636, 0.999920832031223]
training_accuracies_unique_params = [0.967030932534416]

f1_scores_default = [0.6507215979718446, 0.6562012460890234]
f1_scores_max_depth = [0.168417748023534, 0.6377781061822454, 0.6497511557476886, 0.6488135696172306]
f1_scores_max_features = [0.49479969780623934, 0.6127577677303335]
f1_scores_unique_params = [0.7003238103122598]

training_f1_scores_default = [0.9998938545119331, 0.9998930069970788]
training_f1_scores_max_depth = [0.17938183795553145, 0.9408241651481708, 0.9961438634760311, 0.9835923894012069]
training_f1_scores_max_features = [0.9999206118021174, 0.9999114460683203]
training_f1_scores_unique_params = [0.9391370917123293]

# Plotting Default Parameters
x_default = np.arange(len(labels_default))
width = 0.2

fig, ax = plt.subplots(figsize=(8, 6))
rects1 = ax.bar(x_default - width, accuracies_default, width, label='Accuracy')
rects2 = ax.bar(x_default, training_accuracies_default, width, label='Training Accuracy')
rects3 = ax.bar(x_default + width, f1_scores_default, width, label='F1 Score')
rects4 = ax.bar(x_default + (2 * width), training_f1_scores_default, width, label='Training F1 Score')

ax.set_ylabel('Scores')
ax.set_title('Random Forest Default Parameters')
ax.set_xticks(x_default)
ax.set_xticklabels(labels_default)
ax.legend()
plt.tight_layout()
plt.show()

# Plotting Max Depth
x_max_depth = np.arange(len(labels_max_depth))

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x_max_depth - width, accuracies_max_depth, width, label='Accuracy')
rects2 = ax.bar(x_max_depth, training_accuracies_max_depth, width, label='Training Accuracy')
rects3 = ax.bar(x_max_depth + width, f1_scores_max_depth, width, label='F1 Score')
rects4 = ax.bar(x_max_depth + (2 * width), training_f1_scores_max_depth, width, label='Training F1 Score')

ax.set_ylabel('Scores')
ax.set_title('Random Forest Max Depth (5 folds)')
ax.set_xticks(x_max_depth)
ax.set_xticklabels(labels_max_depth)
ax.legend()
plt.tight_layout()
plt.show()

# Plotting Max Features
x_max_features = np.arange(len(labels_max_features))

fig, ax = plt.subplots(figsize=(8, 6))
rects1 = ax.bar(x_max_features - width, accuracies_max_features, width, label='Accuracy')
rects2 = ax.bar(x_max_features, training_accuracies_max_features, width, label='Training Accuracy')
rects3 = ax.bar(x_max_features + width, f1_scores_max_features, width, label='F1 Score')
rects4 = ax.bar(x_max_features + (2 * width), training_f1_scores_max_features, width, label='Training F1 Score')

ax.set_ylabel('Scores')
ax.set_title('Random Forest Max Features (5 folds)')
ax.set_xticks(x_max_features)
ax.set_xticklabels(labels_max_features)
ax.legend()
plt.tight_layout()
plt.show()

# Plotting Unique Parameters
x_unique_params = np.arange(len(labels_unique_params))

fig, ax = plt.subplots(figsize=(6, 6))
rects1 = ax.bar(x_unique_params - width, accuracies_unique_params, width, label='Accuracy')
rects2 = ax.bar(x_unique_params, training_accuracies_unique_params, width, label='Training Accuracy')
rects3 = ax.bar(x_unique_params + width, f1_scores_unique_params, width, label='F1 Score')
rects4 = ax.bar(x_unique_params + (2 * width), training_f1_scores_unique_params, width, label='Training F1 Score')

ax.set_ylabel('Scores')
ax.set_title('Random Forest Unique Parameters (10 folds)')
ax.set_xticks(x_unique_params)
ax.set_xticklabels(labels_unique_params)
ax.legend()
plt.tight_layout()
plt.show()
