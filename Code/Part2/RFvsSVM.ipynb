# %%
import matplotlib.pyplot as plt

# Random Forest data
rf_labels = [
    'Default (5-fold CV)', 'Default (10-fold CV)', 'max_depth=5 (5-fold CV)',
    'max_depth=20 (5-fold CV)', 'max_depth=50 (5-fold CV)', 'max_depth=35 (5-fold CV)',
    'max_features=5 (5-fold CV)', 'max_features=10 (5-fold CV)', 'Unique Parameters (10-fold CV)'
]

rf_accuracies = [
    0.8498642845237103, 0.8518476246041006, 0.7206620746173293, 0.844597505347668,
    0.8485809192432703, 0.8487809234102842, 0.7960466288857405, 0.8350807108925743,
    0.8696145579818859
]

rf_f1_scores = [
    0.6507215979718446, 0.6562012460890234, 0.168417748023534, 0.6377781061822454,
    0.6497511557476886, 0.6488135696172306, 0.49479969780623934, 0.6127577677303335,
    0.7003238103122598
]

rf_training_accuracies = [
    0.9999166653645564, 0.999914813408753, 0.7228578852337202, 0.9678911319333041,
    0.9977791294263074, 0.9907706789898401, 0.9999291654513636, 0.999920832031223,
    0.967030932534416
]

rf_training_f1_scores = [
    0.9998938545119331, 0.9998930069970788, 0.17938183795553145, 0.9408241651481708,
    0.9961438634760311, 0.9835923894012069, 0.9999206118021174, 0.9999114460683203,
    0.9391370917123293
]

# SVM data
svm_labels = [
    'Default (5-fold CV)', 'Default (10-fold CV)', 'C=0.1 (5-fold CV)',
    'C=5 (5-fold CV)', 'kernel="poly" (5-fold CV)'
]

svm_accuracies = [
    0.9102485443231381, 0.9113652219814414, 0.8594143261938495,
    0.919198667944551, 0.8853481248437369
]

svm_f1_scores = [
    0.8169193068243954, 0.8219798269285029, 0.6569836250455194,
    0.8436770480927127, 0.7555651529804173
]

svm_training_accuracies = [
    0.9520283689937985, 0.9516566014939919, 0.8685436461349889,
    0.987770629336028, 0.9306530117814955
]

svm_training_f1_scores = [
    0.9069535775539965, 0.9075479215337869, 0.6828261941251613,
    0.9777224255887262, 0.8590170320232481
]

# Plotting
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))

# Random Forest
ax1 = axes[0, 0]
ax1.plot(rf_labels, rf_accuracies, marker='o', label='Accuracy')
ax1.plot(rf_labels, rf_f1_scores, marker='o', label='F1 Score')
ax1.set_xlabel('Random Forest Configurations')
ax1.set_ylabel('Scores')
ax1.set_title('Random Forest Performance')
ax1.legend()
ax1.tick_params(axis='x', rotation=45)

ax2 = axes[1, 0]
ax2.plot(rf_labels, rf_training_accuracies, marker='o', label='Training Accuracy')
ax2.plot(rf_labels, rf_training_f1_scores, marker='o', label='Training F1 Score')
ax2.set_xlabel('Random Forest Configurations')
ax2.set_ylabel('Scores')
ax2.set_title('Random Forest Training Performance')
ax2.legend()
ax2.tick_params(axis='x', rotation=45)

# SVM
ax3 = axes[0, 1]
ax3.plot(svm_labels, svm_accuracies, marker='o', label='Accuracy')
ax3.plot(svm_labels, svm_f1_scores, marker='o', label='F1 Score')
ax3.set_xlabel('SVM Configurations')
ax3.set_ylabel('Scores')
ax3.set_title('SVM Performance')
ax3.legend()
ax3.tick_params(axis='x', rotation=45)

ax4 = axes[1, 1]
ax4.plot(svm_labels, svm_training_accuracies, marker='o', label='Training Accuracy')
ax4.plot(svm_labels, svm_training_f1_scores, marker='o', label='Training F1 Score')
ax4.set_xlabel('SVM Configurations')
ax4.set_ylabel('Scores')
ax4.set_title('SVM Training Performance')
ax4.legend()
ax4.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Random Forest data
rf_accuracy = [0.8498642845237103, 0.8518476246041006, 0.7206620746173293, 0.844597505347668, 0.8485809192432703, 0.8487809234102842, 0.7960466288857405, 0.8350807108925743, 0.8696145579818859]
rf_f1_score = [0.6507215979718446, 0.6562012460890234, 0.168417748023534, 0.6377781061822454, 0.6497511557476886, 0.6488135696172306, 0.49479969780623934, 0.6127577677303335, 0.7003238103122598]

# SVM data
svm_accuracy = [0.9102485443231381, 0.9113652219814414, 0.8594143261938495, 0.919198667944551, 0.8853481248437369]
svm_f1_score = [0.8169193068243954, 0.8219798269285029, 0.6569836250455194, 0.8436770480927127, 0.7555651529804173]

fig = plt.figure(figsize=(10,5))

plt.plot(rf_accuracy,label='Random Forest')
plt.plot(svm_accuracy,label='SVM')
plt.title('Accuracy Comparison between Random Forest and SVM')
plt.xlabel('Cross Validation')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

fig = plt.figure(figsize=(10,5))

plt.plot(rf_f1_score,label='Random Forest')
plt.plot(svm_f1_score,label='SVM')
plt.title('F1 Score Comparison between Random Forest and SVM')
plt.xlabel('Cross Validation')
plt.ylabel('F1 Score')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random Forest data
labels_rf = ['Default (5-fold CV)', 'Default (10-fold CV)', 'Max Depth=5', 'Max Depth=20', 'Max Depth=50', 'Max Depth=35', 'Max Features=5', 'Max Features=10', 'Unique Parameters']
accuracies_rf = [0.8498642845237103, 0.8518476246041006, 0.7206620746173293, 0.844597505347668, 0.8485809192432703, 0.8487809234102842, 0.7960466288857405, 0.8350807108925743, 0.8696145579818859]
f1_scores_rf = [0.6507215979718446, 0.6562012460890234, 0.168417748023534, 0.6377781061822454, 0.6497511557476886, 0.6488135696172306, 0.49479969780623934, 0.6127577677303335, 0.7003238103122598]
training_accuracies_rf = [0.9999166653645564, 0.999914813408753, 0.7228578852337202, 0.9678911319333041, 0.9977791294263074, 0.9907706789898401, 0.9999291654513636, 0.999920832031223, 0.967030932534416]
training_f1_scores_rf = [0.9998938545119331, 0.9998930069970788, 0.17938183795553145, 0.9408241651481708, 0.9961438634760311, 0.9835923894012069, 0.9999206118021174, 0.9999114460683203, 0.9391370917123293]

# SVM data
labels_svm = ['Default (5-fold CV)', 'Default (10-fold CV)', 'C=0.1', 'C=5', 'Kernel="poly"']
accuracies_svm = [0.9102485443231381, 0.9113652219814414, 0.8594143261938495, 0.919198667944551, 0.8853481248437369]
f1_scores_svm = [0.8169193068243954, 0.8219798269285029, 0.6569836250455194, 0.8436770480927127, 0.7555651529804173]
training_accuracies_svm = [0.9520283689937985, 0.9516566014939919, 0.8685436461349889, 0.987770629336028, 0.9306530117814955]
training_f1_scores_svm = [0.9069535775539965, 0.9075479215337869, 0.6828261941251613, 0.9777224255887262, 0.8590170320232481]

# Plotting Random Forest data
plt.figure(figsize=(12, 6))

# Accuracy and F1 Score
plt.subplot(1, 2, 1)
x = np.arange(len(labels_rf))
width = 0.35
plt.bar(x - width/2, accuracies_rf, width, label='Accuracy')
plt.bar(x + width/2, f1_scores_rf, width, label='F1 Score')
plt.xlabel('Random Forest Models')
plt.ylabel('Scores')
plt.title('Random Forest - Accuracy and F1 Score')
plt.xticks(x, labels_rf, rotation=90)
plt.legend()

# Training Accuracy and Training F1 Score
plt.subplot(1, 2, 2)
plt.bar(x - width/2, training_accuracies_rf, width, label='Training Accuracy')
plt.bar(x + width/2, training_f1_scores_rf, width, label='Training F1 Score')
plt.xlabel('Random Forest Models')
plt.ylabel('Scores')
plt.title('Random Forest - Training Accuracy and Training F1 Score')
plt.xticks(x, labels_rf, rotation=90)
plt.legend()

plt.tight_layout()

# Plotting SVM data
plt.figure(figsize=(8, 6))

# Accuracy and F1 Score
plt.subplot(1, 2, 1)
x = np.arange(len(labels_svm))
plt.bar(x - width/2, accuracies_svm, width, label='Accuracy')
plt.bar(x + width/2, f1_scores_svm, width, label='F1 Score')
plt.xlabel('SVM Models')
plt.ylabel('Scores')
plt.title('SVM - Accuracy and F1 Score')
plt.xticks(x, labels_svm, rotation=90)
plt.legend()

# Training Accuracy and Training F1 Score
plt.subplot(1, 2, 2)
plt.bar(x - width/2, training_accuracies_svm, width, label='Training Accuracy')
plt.bar(x + width/2, training_f1_scores_svm, width, label='Training F1 Score')
plt.xlabel('SVM Models')
plt.ylabel('Scores')
plt.title('SVM - Training Accuracy and Training F1 Score')
plt.xticks(x, labels_svm, rotation=90)
plt.legend()

plt.tight_layout()
plt.show()
