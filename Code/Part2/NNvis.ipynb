# %%
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# Bar chart example using Matplotlib
x = [
    '5-fold cross-validation with default parameters',
    '10-fold cross-validation with default parameters',
    '5-fold cross-validation with alpha=0.01',
    '5-fold cross-validation with alpha=1',
    '5-fold cross-validation with alpha=10',
    '5-fold cross-validation with hidden_layer_sizes=(100,50)',
    '5-fold cross-validation with hidden_layer_sizes=(100, 100, 50)',
    "5-fold cross-validation with unique parameters(hidden_layer_sizes=(100, 50), alpha=1, solver='adam', activation='relu', learning_rate='adaptive', max_iter=200)"
]
accuracy = [
    0.8973483179153818, 0.9011816747235649, 0.8990150206961692,
    0.911348540156124, 0.8684311637080867, 0.9022816665277661,
    0.8992315929105203, 0.9104818554323971
]

fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(x, accuracy)
ax.set_title('Accuracy of Neural Network (Multi-layer Perceptron classifier) Model')
ax.set_xlabel('Cross Validation')
ax.set_ylabel('Accuracy')

plt.xticks(rotation=45)
plt.subplots_adjust(top=0.9, bottom=0.2)  # Manually adjust the margins

plt.show()

# Histogram example using Plotly
hist_data = [accuracy]
group_labels = ['Accuracy']

fig = go.Figure()
for i, data in enumerate(hist_data):
    fig.add_trace(go.Histogram(x=data, name=group_labels[i]))

fig.update_layout(
    title='Accuracy Distribution of Neural Network (Multi-layer Perceptron classifier) Model',
    xaxis_title='Accuracy',
    yaxis_title='Count'
)

fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Results data
labels = [
    'Default (5-fold CV)', 'Default (10-fold CV)', 'alpha=0.01 (5-fold CV)',
    'alpha=1 (5-fold CV)', 'alpha=10 (5-fold CV)', 'hidden_layer_sizes=(100, 50) (5-fold CV)',
    'hidden_layer_sizes=(100, 100, 50) (5-fold CV)', 'hidden_layer_sizes=(100, 100, 100, 100) (5-fold CV)',
    'Unique Parameters (5-fold CV)'
]

accuracies = [
    0.8973483179153818, 0.9011816747235649, 0.8990150206961692,
    0.911348540156124, 0.8684311637080867, 0.9022816665277661,
    0.8992315929105203, 0.8995816429146872, 0.9104818554323971
]

f1_scores = [
    0.8006921301430111, 0.8084369876724053, 0.8042310550062298,
    0.8203034176255903, 0.6815909694653289, 0.8121034954261823,
    0.8049075540202008, 0.8069268859950898, 0.823201031677069
]

training_accuracies = [
    0.999729161979069, 0.9997296250685025, 0.9996958277776621,
    0.9398448284512873, 0.8713603496079779, 0.9998333307291125,
    0.9970957901900734, 0.9967666211796079, 0.9574992892213032
]

training_f1_scores = [
    0.9994850675582849, 0.9996400954325411, 0.9996345553469828,
    0.8783286200648023, 0.6876611606859893, 0.9998107879159586,
    0.9948547121265833, 0.9937670246610851, 0.9124209346160888
]

# Plotting
x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots(figsize=(16, 6))

rects1 = ax.bar(x - width, accuracies, width, label='Accuracy')
rects2 = ax.bar(x, f1_scores, width, label='F1 Score')
rects3 = ax.bar(x + width, training_accuracies, width, label='Training Accuracy')
rects4 = ax.bar(x + (2 * width), training_f1_scores, width, label='Training F1 Score')

ax.set_ylabel('Scores')
ax.set_title('Neural Network Results')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)
ax.legend()
ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
# Add data labels
def add_labels(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.3f}', xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 5), textcoords="offset points", ha='center', va='bottom')
add_labels(rects1)
add_labels(rects2)
add_labels(rects3)
add_labels(rects4)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Default data
labels_default = ['Default (5-fold CV)', 'Default (10-fold CV)']
accuracies_default = [0.8973483179153818, 0.9011816747235649]
f1_scores_default = [0.8006921301430111, 0.8084369876724053]
training_accuracies_default = [0.999729161979069, 0.9997296250685025]
training_f1_scores_default = [0.9994850675582849, 0.9996400954325411]

# Alpha data
labels_alpha = ['Alpha=0.01 (5-fold CV)', 'Alpha=1 (5-fold CV)', 'Alpha=10 (5-fold CV)']
accuracies_alpha = [0.8990150206961692, 0.911348540156124, 0.8684311637080867]
f1_scores_alpha = [0.8042310550062298, 0.8203034176255903, 0.6815909694653289]
training_accuracies_alpha = [0.9996958277776621, 0.9398448284512873, 0.8713603496079779]
training_f1_scores_alpha = [0.9996345553469828, 0.8783286200648023, 0.6876611606859893]

# Hidden Layer Size data
labels_hidden_layer_size = [
    'Hidden Layer Sizes=(100, 50) (5-fold CV)',
    'Hidden Layer Sizes=(100, 100, 50) (5-fold CV)',
    'Hidden Layer Sizes=(100, 100, 100, 100) (5-fold CV)'
]
accuracies_hidden_layer_size = [0.9022816665277661, 0.8992315929105203, 0.8995816429146872]
f1_scores_hidden_layer_size = [0.8121034954261823, 0.8049075540202008, 0.8069268859950898]
training_accuracies_hidden_layer_size = [0.9998333307291125, 0.9970957901900734, 0.9967666211796079]
training_f1_scores_hidden_layer_size = [0.9998107879159586, 0.9948547121265833, 0.9937670246610851]

# Unique parameters data
labels_unique = [
    'Unique Parameters (5-fold CV)'
]
accuracies_unique = [0.9104818554323971]
f1_scores_unique = [0.823201031677069]
training_accuracies_unique = [0.9574992892213032]
training_f1_scores_unique = [0.9124209346160888]

# Plotting Default (2 folds)
x_default = np.arange(2)
width = 0.2

fig, ax = plt.subplots(figsize=(8, 6))
rects1 = ax.bar(x_default - width, accuracies_default, width, label='Accuracy')
rects2 = ax.bar(x_default, f1_scores_default, width, label='F1 Score')
rects3 = ax.bar(x_default + width, training_accuracies_default, width, label='Training Accuracy')
rects4 = ax.bar(x_default + (2 * width), training_f1_scores_default, width, label='Training F1 Score')

ax.set_ylabel('Scores')
ax.set_title('Default Parameters')
ax.set_xticks(x_default + width)
ax.set_xticklabels(labels_default)
ax.legend()

plt.show()

# Plotting Alpha (3 folds)
x_alpha = np.arange(3)
width = 0.2

fig, ax = plt.subplots(figsize=(8, 6))
rects1 = ax.bar(x_alpha - width, accuracies_alpha, width, label='Accuracy')
rects2 = ax.bar(x_alpha, f1_scores_alpha, width, label='F1 Score')
rects3 = ax.bar(x_alpha + width, training_accuracies_alpha, width, label='Training Accuracy')
rects4 = ax.bar(x_alpha + (2 * width), training_f1_scores_alpha, width, label='Training F1 Score')

ax.set_ylabel('Scores')
ax.set_title('Alpha')
ax.set_xticks(x_alpha + width)
ax.set_xticklabels(labels_alpha)
ax.legend()

plt.show()

# Plotting Hidden Layer Size (3 folds)
x_hidden_layer_size = np.arange(3)
width = 0.2

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x_hidden_layer_size - width, accuracies_hidden_layer_size, width, label='Accuracy')
rects2 = ax.bar(x_hidden_layer_size, f1_scores_hidden_layer_size, width, label='F1 Score')
rects3 = ax.bar(x_hidden_layer_size + width, training_accuracies_hidden_layer_size, width, label='Training Accuracy')
rects4 = ax.bar(x_hidden_layer_size + (2 * width), training_f1_scores_hidden_layer_size, width, label='Training F1 Score')

ax.set_ylabel('Scores')
ax.set_title('Hidden Layer Sizes')
ax.set_xticks(x_hidden_layer_size + width)
ax.set_xticklabels(labels_hidden_layer_size, rotation=90)
ax.legend()

plt.show()

# Plotting Unique Parameters (1 fold)
x_unique = np.arange(1)
width = 0.2

fig, ax = plt.subplots(figsize=(6, 6))
rects1 = ax.bar(x_unique, accuracies_unique, width, label='Accuracy')
rects2 = ax.bar(x_unique + width, f1_scores_unique, width, label='F1 Score')
rects3 = ax.bar(x_unique + (2 * width), training_accuracies_unique, width, label='Training Accuracy')
rects4 = ax.bar(x_unique + (3 * width), training_f1_scores_unique, width, label='Training F1 Score')

ax.set_ylabel('Scores')
ax.set_title('Unique Parameters')
ax.set_xticks(x_unique + width)
ax.set_xticklabels(labels_unique)
ax.legend()

plt.show()
